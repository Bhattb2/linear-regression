# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
fat_supply = pd.read_csv("./Fat_Supply_Quantity_Data.csv").dropna()
print(f"Data Shape for st_mat: {fat_supply.shape}")
# Out:
# Data Shape for st_mat: (154, 32)

# %% [markdown]
# ## First Five Rows Of The DataSet

# %%
fat_supply.head()
# Out:
#        Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0  Afghanistan                  0.0          21.6397       6.2224
# 1      Albania                  0.0          32.0002       3.4172
# 2      Algeria                  0.0          14.4175       0.8972
# 3       Angola                  0.0          15.3041       1.3130
# 5    Argentina                  0.0          30.3572       3.3076
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 5                      0.0                    1.3316  1.5706         0.1664
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   0.4246   6.1244  ...         17.0831      0.3593      4.5
# 1                   0.6418   8.7428  ...          9.2443      0.6503     22.3
# 2                   0.5772   3.8961  ...         27.3606      0.5145     26.6
# 3                   0.3488  11.0268  ...         22.4638      0.1231      6.8
# 5                   0.2091  19.2693  ...         17.3147      0.1878     28.5
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.138283  0.005970   0.116713  0.015601  38928000.0
# 1             6.2   2.347956  0.044574   1.396230  0.907153   2838000.0
# 2             3.9   0.233066  0.006373   0.158234  0.068458  44357000.0
# 3              25   0.057435  0.001316   0.049566  0.006552  32522000.0
# 5             4.6   3.929407  0.099669   3.442191  0.387547  45377000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 5                             %
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Description and Information on Data Set

# %%
fat_supply.describe
# Out:
# <bound method NDFrame.describe of                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 5                             Argentina               0.0000          30.3572
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 0         6.2224                      0.0                    8.0353  0.6859
# 1         3.4172                      0.0                    2.6734  1.6448
# 2         0.8972                      0.0                    4.2035  1.2171
# 3         1.3130                      0.0                    6.5545  0.1539
# 5         3.3076                      0.0                    1.3316  1.5706
# ..           ...                      ...                       ...     ...
# 165       2.2673                      0.0                    2.5449  0.6555
# 166       3.8238                      0.0                    3.7155  0.7839
# 167       2.0131                      0.0                   11.5271  0.5514
# 168       1.6113                      0.0                   14.3225  0.6266
# 169       2.9543                      0.0                    9.7922  0.3682
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetable Oils  \
# 0           0.0327                   0.4246   6.1244  ...         17.0831
# 1           0.1445                   0.6418   8.7428  ...          9.2443
# 2           0.2008                   0.5772   3.8961  ...         27.3606
# 3           1.4155                   0.3488  11.0268  ...         22.4638
# 5           0.1664                   0.2091  19.2693  ...         17.3147
# ..             ...                      ...      ...  ...             ...
# 165         0.5707                   0.9640   7.0949  ...         29.5211
# 166         1.1217                   0.4079  26.4292  ...          5.6211
# 167         0.3847                   0.2564   8.0010  ...         23.6312
# 168         1.0070                   0.1343   4.9010  ...         15.2848
# 169         0.2455                   0.0614   4.5674  ...         26.9396
#
#      Vegetables  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0        0.3593      4.5            29.8   0.138283  0.005970   0.116713
# 1        0.6503     22.3             6.2   2.347956  0.044574   1.396230
# 2        0.5145     26.6             3.9   0.233066  0.006373   0.158234
# 3        0.1231      6.8              25   0.057435  0.001316   0.049566
# 5        0.1878     28.5             4.6   3.929407  0.099669   3.442191
# ..          ...      ...             ...        ...       ...        ...
# 165      0.1851     25.2            21.2   0.414928  0.003823   0.392110
# 166      0.6373      2.1             9.3   0.001597  0.000036   0.001434
# 167      0.1667     14.1            38.9   0.007078  0.002052   0.004758
# 168      0.1567      6.5            46.7   0.186456  0.002867   0.131119
# 169      0.0789     12.3            51.3   0.175664  0.004481   0.103707
#
#        Active  Population  Unit (all except Population)
# 0    0.015601  38928000.0                             %
# 1    0.907153   2838000.0                             %
# 2    0.068458  44357000.0                             %
# 3    0.006552  32522000.0                             %
# 5    0.387547  45377000.0                             %
# ..        ...         ...                           ...
# 165  0.018995  28645000.0                             %
# 166  0.000126  96209000.0                             %
# 167  0.000268  29826000.0                             %
# 168  0.052470  18384000.0                             %
# 169  0.067476  14863000.0                             %
#
# [154 rows x 32 columns]>

# %%
fat_supply.shape
# Out:
# (154, 32)

# %%
fat_supply.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal Products', 'Animal fats',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Miscellaneous',
#        'Milk - Excluding Butter', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar Crops', 'Sugar & Sweeteners',
#        'Treenuts', 'Vegetal Products', 'Vegetable Oils', 'Vegetables',
#        'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %% [markdown]
# ## Linear Regression of Animal Fats vs Deaths

# %%
X = fat_supply['Animal fats'].values
y = fat_supply['Deaths'].values

# %%
X = X.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=100)
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_test shape {x_test.shape}")
print(f"y_test shape {y_test.shape}")
print(y_test)
# Out:
# X_train shape (123, 1)
# y_train shape (123,)
# X_test shape (31, 1)
# y_test shape (31,)
# [0.00022321 0.01668267 0.01801604 0.08227456 0.14840704 0.03416954
#  0.00143604 0.04457364 0.00302198 0.04331541 0.02266626 0.00166074
#  0.00034199 0.0134469  0.         0.06115751 0.0084055  0.00057051
#  0.00322448 0.00901251 0.01086301 0.11318408 0.06155254 0.04727059
#  0.         0.00448093 0.         0.00046405 0.02018759 0.
#  0.00382266]

# %%
# %matplotlib inline
plt.scatter(x_train, y_train, color = 'red')
plt.xlabel('Animal Fats')
plt.ylabel('Deaths')
plt.title('Aminal Fats and Deaths')
plt.show()

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train, y_train)*100, 2)} %")
print(f"Test accuracy {round(lm.score(x_test, y_test)*100, 2)}%")
# Out:
# Train accuracy 25.84 %
# Test accuracy 8.78%

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_predict)
plt.xlabel("Animal Fats")
plt.ylabel("Deaths")
plt.title("Trained model plot")
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
import seaborn as sns
sns.set()

# %%
fat_supply.head()
# Out:
#        Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0  Afghanistan                  0.0          21.6397       6.2224
# 1      Albania                  0.0          32.0002       3.4172
# 2      Algeria                  0.0          14.4175       0.8972
# 3       Angola                  0.0          15.3041       1.3130
# 5    Argentina                  0.0          30.3572       3.3076
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 5                      0.0                    1.3316  1.5706         0.1664
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   0.4246   6.1244  ...         17.0831      0.3593      4.5
# 1                   0.6418   8.7428  ...          9.2443      0.6503     22.3
# 2                   0.5772   3.8961  ...         27.3606      0.5145     26.6
# 3                   0.3488  11.0268  ...         22.4638      0.1231      6.8
# 5                   0.2091  19.2693  ...         17.3147      0.1878     28.5
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.138283  0.005970   0.116713  0.015601  38928000.0
# 1             6.2   2.347956  0.044574   1.396230  0.907153   2838000.0
# 2             3.9   0.233066  0.006373   0.158234  0.068458  44357000.0
# 3              25   0.057435  0.001316   0.049566  0.006552  32522000.0
# 5             4.6   3.929407  0.099669   3.442191  0.387547  45377000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 5                             %
#
# [5 rows x 32 columns]

# %%
sns.regplot(x = 'Animal fats', y = 'Deaths', data = fat_supply, order = 1)
# Out:
# <AxesSubplot:xlabel='Animal fats', ylabel='Deaths'>

# %%
sns.regplot(x = 'Animal fats', y= 'Deaths', data = fat_supply, order =2)
# Out:
# <AxesSubplot:xlabel='Animal fats', ylabel='Deaths'>

# %%
sns.lmplot(x = 'Animal fats', y= 'Deaths', data = fat_supply,ci=None, scatter_kws={"s": 80})

# %% [markdown]
# ## Conclusion
#
# The data is sourced from Kaggle COVID19_eating, which was used to examine the fat_supply_quantity_data.csv file.
#
# 1. There is positive correlation between the Animal fats consumption and the number of deaths by COVID19, which translates into: the more Animal Fats were consumed, there was higher likelihood of death.
#
# 1. The graph is the using seaborn with order-2 which accounts for the decrease in the deaths with very high animal fat consumption. This may be possible because higher animal fat consumption occurs in countries with high GDP and so possibly lower deaths than in poorer, underproverished countries.
#
# 2. Since most developing countries have middle of the range animal fat consumption (assumption), they also have higher death rate, than the well proverished, higher GDP countries with higher animal fat consumption.
